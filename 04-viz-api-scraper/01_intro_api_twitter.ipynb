# %% [markdown]
# [![AnalyticsDojo](../fig/final-logo.png)](http://rpi.analyticsdojo.com)
# <center><h1>Introduction to API's with Python</h1></center>
# <center><h3><a href = 'http://rpi.analyticsdojo.com'>rpi.analyticsdojo.com</a></h3></center>

# %% [markdown]
# This is adopted from [Mining the Social Web, 2nd Edition](http://bit.ly/16kGNyb)
# Copyright (c) 2013, Matthew A. Russell
# All rights reserved.
#
# This work is licensed under the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt).

# %% [markdown]
# ### Before you Begin #1
# If you are working locally or on colab, this exercise requires the twitter package.
# `!pip install twitter`

# %%
 # !pip install twitter

# %%
#see if it worked by importing the twitter package & some other things we will use.  
from  twitter import *
import datetime, traceback 
import json
import time
import sys

# %% [markdown]
# ### Before you Begin #2
# Download the sample configuration.

# %%
# !wget <see filename on slack>

# %% [markdown]
# ## Step1.  Loading Authorization Data
# - Here we are going to store the authorization data in a .YAML file rather than directly in the notebook.
# - We have also added `config.yaml` to the `.gitignore` file so we won't accidentally commit our sensitive data to the repository.
# - You should generally keep sensitive data out of all git repositories (public or private) but definitely Public.
# - If you ever accidentally commit data to a public repository you must consider it compromised.
# - A .yaml file is a common way to store configuration data, but it is not really secure.

# %%
#This will import some required libraries.
import sys 
import ruamel.yaml #A .yaml file 
#This is your configuration file. 
twitter_yaml='config.yaml'
with open(twitter_yaml, 'r') as yaml_t:
    cf_t=ruamel.yaml.round_trip_load(yaml_t, preserve_quotes=True)

#You can check your config was loaded by printing, but you should not commit this.
#print(cf_t)
cf_t['file']
# Out:
# 'screen_names.csv'

# %% [markdown]
# ## Create Some Relevant Functions
# - We first will create a Twitter object we can used to authorize data.
# - Then we will get profiles.
# - Finally we will get some tweets.
#
# **Don't worry about not understanding all the code.  Here we are pushing you us more complex functions.**

# %%
def create_twitter_auth(cf_t):
        """Function to create a twitter object
           Args: cf_t is configuration dictionary. 
           Returns: Twitter object.
            """
        # When using twitter stream you must authorize.
        # these tokens are necessary for user authentication
        # create twitter API object

        auth = OAuth(cf_t['access_token'], cf_t['access_token_secret'], cf_t['consumer_key'], cf_t['consumer_secret'])

        try:
            # create twitter API object
            twitter = Twitter(auth = auth)
        except TwitterHTTPError:
            traceback.print_exc()
            time.sleep(cf_t['sleep_interval'])
        return twitter

# %%
def get_profiles(twitter, names, cf_t):
    """Function write profiles to a file with the form *data-user-profiles.json*
       Args: names is a list of names
             cf_t is a list of twitter config
       Returns: Nothing
        """
    # file name for daily tracking
    dt = datetime.datetime.now()
    fn = cf_t['data']+'/profiles/'+dt.strftime('%Y-%m-%d-user-profiles.json')
    with open(fn, 'w') as f:
        for name in names:
            print("Searching twitter for User profile: ", name)
            try:
                # create a subquery, looking up information about these users
                # twitter API docs: https://dev.twitter.com/docs/api/1/get/users/lookup
                profiles = twitter.users.lookup(screen_name = name)
                sub_start_time = time.time()
                for profile in profiles:
                    print("User found. Total tweets:", profile['statuses_count'])
                    # now save user info
                    f.write(json.dumps(profile))
                    f.write("\n")
                sub_elapsed_time = time.time() - sub_start_time;
                if sub_elapsed_time < cf_t['sleep_interval']:
                    time.sleep(cf_t['sleep_interval'] + 1 - sub_elapsed_time)
            except TwitterHTTPError:
                traceback.print_exc()
                time.sleep(cf_t['sleep_interval'])
                continue
    f.close()
    return fn

# %% [markdown]
# ## Load Twitter Handle From CSV
# - This is a .csv that has individuals we want to collect data on.
# - Go ahead and follow [AnalyticsDojo](https://twitter.com/AnalyticsDojo).

# %%
import pandas as pd
df=pd.read_csv(cf_t['config']+"/"+cf_t['file'])
df
# Out:
#    index      screen_name
# 0      1       tensorflow
# 1      2  DeepLearningHub

# %% [markdown]
# ## Create Twitter Object

# %%
import twitlab

# %%
#Create Twitter Object
twitter= twitlab.create_twitter_auth(cf_t)

# %%
df['screen_name']
# Out:
# 0         tensorflow
# 1    DeepLearningHub
# Name: screen_name, dtype: object

# %%
#This will get general profile data
profiles_fn=twitlab.get_profiles(twitter, df['screen_name'], cf_t)
# Out:
# Searching twitter for User profile:  tensorflow
# User found. Total tweets: 426
# Searching twitter for User profile:  DeepLearningHub
# User found. Total tweets: 2431

# %% [markdown]
# The outcoming of running the above API is to generate a twitter object.

# %% [markdown]
# ## Step 2. Getting Help

# %%
# We can get some help on how to use the twitter api with the following. 
help(twitter)
# Out:
# Help on Twitter in module twitter.api object:
#
# class Twitter(TwitterCall)
#  |  The minimalist yet fully featured Twitter API class.
#  |
#  |  Get RESTful data by accessing members of this class. The result
#  |  is decoded python objects (lists and dicts).
#  |
#  |  The Twitter API is documented at:
#  |
#  |    https://dev.twitter.com/overview/documentation
#  |
#  |  The list of most accessible functions is listed at:
#  |
#  |    https://dev.twitter.com/rest/public
#  |
#  |
#  |  Examples::
#  |
#  |      from twitter import *
#  |
#  |      t = Twitter(
#  |          auth=OAuth(token, token_secret, consumer_key, consumer_secret))
#  |
#  |      # Get your "home" timeline
#  |      t.statuses.home_timeline()
#  |
#  |      # Get a particular friend's timeline
#  |      t.statuses.user_timeline(screen_name="billybob")
#  |
#  |      # to pass in GET/POST parameters, such as `count`
#  |      t.statuses.home_timeline(count=5)
#  |
#  |      # to pass in the GET/POST parameter `id` you need to use `_id`
#  |      t.statuses.oembed(_id=1234567890)
#  |
#  |      # Update your status
#  |      t.statuses.update(
#  |          status="Using @sixohsix's sweet Python Twitter Tools.")
#  |
#  |      # Send a direct message
#  |      t.direct_messages.new(
#  |          user="billybob",
#  |          text="I think yer swell!")
#  |
#  |      # Get the members of tamtar's list "Things That Are Rad"
#  |      t.lists.members(owner_screen_name="tamtar", slug="things-that-are-rad")
#  |
#  |      # An *optional* `_timeout` parameter can also be used for API
#  |      # calls which take much more time than normal or twitter stops
#  |      # responding for some reason:
#  |      t.users.lookup(
#  |          screen_name=','.join(A_LIST_OF_100_SCREEN_NAMES),             _timeout=1)
#  |
#  |      # Overriding Method: GET/POST
#  |      # you should not need to use this method as this library properly
#  |      # detects whether GET or POST should be used, Nevertheless
#  |      # to force a particular method, use `_method`
#  |      t.statuses.oembed(_id=1234567890, _method='GET')
#  |
#  |      # Send images along with your tweets:
#  |      # - first just read images from the web or from files the regular way:
#  |      with open("example.png", "rb") as imagefile:
#  |          imagedata = imagefile.read()
#  |      # - then upload medias one by one on Twitter's dedicated server
#  |      #   and collect each one's id:
#  |      t_upload = Twitter(domain='upload.twitter.com',
#  |          auth=OAuth(token, token_secret, consumer_key, consumer_secret))
#  |      id_img1 = t_upload.media.upload(media=imagedata)["media_id_string"]
#  |      id_img2 = t_upload.media.upload(media=imagedata)["media_id_string"]
#  |
#  |      # - finally send your tweet with the list of media ids:
#  |      t.statuses.update(status="PTT ★", media_ids=",".join([id_img1, id_img2]))
#  |
#  |      # Or send a tweet with an image (or set a logo/banner similarily)
#  |      # using the old deprecated method that will probably disappear some day
#  |      params = {"media[]": imagedata, "status": "PTT ★"}
#  |      # Or for an image encoded as base64:
#  |      params = {"media[]": base64_image, "status": "PTT ★", "_base64": True}
#  |      t.statuses.update_with_media(**params)
#  |
#  |      # Attach text metadata to medias sent, using the upload.twitter.com route
#  |      # using the _json workaround to send json arguments as POST body
#  |      # (warning: to be done before attaching the media to a tweet)
#  |      t_upload.media.metadata.create(_json={
#  |        "media_id": id_img1,
#  |        "alt_text": { "text": "metadata generated via PTT!" }
#  |      })
#  |      # or with the shortcut arguments ("alt_text" and "text" work):
#  |      t_upload.media.metadata.create(media_id=id_img1, text="metadata generated via PTT!")
#  |
#  |  Searching Twitter::
#  |
#  |      # Search for the latest tweets about #pycon
#  |      t.search.tweets(q="#pycon")
#  |
#  |
#  |  Using the data returned
#  |  -----------------------
#  |
#  |  Twitter API calls return decoded JSON. This is converted into
#  |  a bunch of Python lists, dicts, ints, and strings. For example::
#  |
#  |      x = twitter.statuses.home_timeline()
#  |
#  |      # The first 'tweet' in the timeline
#  |      x[0]
#  |
#  |      # The screen name of the user who wrote the first 'tweet'
#  |      x[0]['user']['screen_name']
#  |
#  |
#  |  Getting raw XML data
#  |  --------------------
#  |
#  |  If you prefer to get your Twitter data in XML format, pass
#  |  format="xml" to the Twitter object when you instantiate it::
#  |
#  |      twitter = Twitter(format="xml")
#  |
#  |  The output will not be parsed in any way. It will be a raw string
#  |  of XML.
#  |
#  |  Method resolution order:
#  |      Twitter
#  |      TwitterCall
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, format='json', domain='api.twitter.com', secure=True, auth=None, api_version=<class 'twitter.api._DEFAULT'>, retry=False)
#  |      Create a new twitter API connector.
#  |
#  |      Pass an `auth` parameter to use the credentials of a specific
#  |      user. Generally you'll want to pass an `OAuth`
#  |      instance::
#  |
#  |          twitter = Twitter(auth=OAuth(
#  |                  token, token_secret, consumer_key, consumer_secret))
#  |
#  |
#  |      `domain` lets you change the domain you are connecting. By
#  |      default it's `api.twitter.com`.
#  |
#  |      If `secure` is False you will connect with HTTP instead of
#  |      HTTPS.
#  |
#  |      `api_version` is used to set the base uri. By default it's
#  |      '1.1'.
#  |
#  |      If `retry` is True, API rate limits will automatically be
#  |      handled by waiting until the next reset, as indicated by
#  |      the X-Rate-Limit-Reset HTTP header. If retry is an integer,
#  |      it defines the number of retries attempted.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from TwitterCall:
#  |
#  |  __call__(self, **kwargs)
#  |      Call self as a function.
#  |
#  |  __getattr__(self, k)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from TwitterCall:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from TwitterCall:
#  |
#  |  TWITTER_UNAVAILABLE_WAIT = 30

# %% [markdown]
# Go ahead and take a look at the [twitter docs](https://dev.twitter.com/rest/public).

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter.trends.place(_id=US_WOE_ID)

print (world_trends)
print (us_trends)
# Out:
# [{'trends': [{'name': '#NationalVoterRegistrationDay', 'url': 'http://twitter.com/search?q=%23NationalVoterRegistrationDay', 'promoted_content': None, 'query': '%23NationalVoterRegistrationDay', 'tweet_volume': 31490}, {'name': 'Caputo', 'url': 'http://twitter.com/search?q=Caputo', 'promoted_content': None, 'query': 'Caputo', 'tweet_volume': 33073}, {'name': '#FelizMartes', 'url': 'http://twitter.com/search?q=%23FelizMartes', 'promoted_content': None, 'query': '%23FelizMartes', 'tweet_volume': 36370}, {'name': '#FantasticBeasts', 'url': 'http://twitter.com/search?q=%23FantasticBeasts', 'promoted_content': None, 'query': '%23FantasticBeasts', 'tweet_volume': 94250}, {'name': '#INDvAFG', 'url': 'http://twitter.com/search?q=%23INDvAFG', 'promoted_content': None, 'query': '%23INDvAFG', 'tweet_volume': 31758}, {'name': '#EleSimENo1Turno', 'url': 'http://twitter.com/search?q=%23EleSimENo1Turno', 'promoted_content': None, 'query': '%23EleSimENo1Turno', 'tweet_volume': 43322}, {'name': '내기니', 'url': 'http://twitter.com/search?q=%EB%82%B4%EA%B8%B0%EB%8B%88', 'promoted_content': None, 'query': '%EB%82%B4%EA%B8%B0%EB%8B%88', 'tweet_volume': 11714}, {'name': 'Meltan', 'url': 'http://twitter.com/search?q=Meltan', 'promoted_content': None, 'query': 'Meltan', 'tweet_volume': 20252}, {'name': 'メルタン', 'url': 'http://twitter.com/search?q=%E3%83%A1%E3%83%AB%E3%82%BF%E3%83%B3', 'promoted_content': None, 'query': '%E3%83%A1%E3%83%AB%E3%82%BF%E3%83%B3', 'tweet_volume': 85511}, {'name': 'Michael Kors', 'url': 'http://twitter.com/search?q=%22Michael+Kors%22', 'promoted_content': None, 'query': '%22Michael+Kors%22', 'tweet_volume': 37676}, {'name': '조니뎁', 'url': 'http://twitter.com/search?q=%EC%A1%B0%EB%8B%88%EB%8E%81', 'promoted_content': None, 'query': '%EC%A1%B0%EB%8B%88%EB%8E%81', 'tweet_volume': None}, {'name': 'Toto', 'url': 'http://twitter.com/search?q=Toto', 'promoted_content': None, 'query': 'Toto', 'tweet_volume': 26782}, {'name': '신동사', 'url': 'http://twitter.com/search?q=%EC%8B%A0%EB%8F%99%EC%82%AC', 'promoted_content': None, 'query': '%EC%8B%A0%EB%8F%99%EC%82%AC', 'tweet_volume': None}, {'name': '볼드모트', 'url': 'http://twitter.com/search?q=%EB%B3%BC%EB%93%9C%EB%AA%A8%ED%8A%B8', 'promoted_content': None, 'query': '%EB%B3%BC%EB%93%9C%EB%AA%A8%ED%8A%B8', 'tweet_volume': 10826}, {'name': '新潮45', 'url': 'http://twitter.com/search?q=%E6%96%B0%E6%BD%AE45', 'promoted_content': None, 'query': '%E6%96%B0%E6%BD%AE45', 'tweet_volume': 47201}, {'name': 'ヤクルト', 'url': 'http://twitter.com/search?q=%E3%83%A4%E3%82%AF%E3%83%AB%E3%83%88', 'promoted_content': None, 'query': '%E3%83%A4%E3%82%AF%E3%83%AB%E3%83%88', 'tweet_volume': 58889}, {'name': '말레딕투스', 'url': 'http://twitter.com/search?q=%EB%A7%90%EB%A0%88%EB%94%95%ED%88%AC%EC%8A%A4', 'promoted_content': None, 'query': '%EB%A7%90%EB%A0%88%EB%94%95%ED%88%AC%EC%8A%A4', 'tweet_volume': None}, {'name': 'Marlaska', 'url': 'http://twitter.com/search?q=Marlaska', 'promoted_content': None, 'query': 'Marlaska', 'tweet_volume': 51515}, {'name': 'Faltam 12', 'url': 'http://twitter.com/search?q=%22Faltam+12%22', 'promoted_content': None, 'query': '%22Faltam+12%22', 'tweet_volume': None}, {'name': '해리포터', 'url': 'http://twitter.com/search?q=%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0', 'promoted_content': None, 'query': '%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0', 'tweet_volume': None}, {'name': 'Thames', 'url': 'http://twitter.com/search?q=Thames', 'promoted_content': None, 'query': 'Thames', 'tweet_volume': None}, {'name': 'Sauber', 'url': 'http://twitter.com/search?q=Sauber', 'promoted_content': None, 'query': 'Sauber', 'tweet_volume': None}, {'name': '#YoNoParo', 'url': 'http://twitter.com/search?q=%23YoNoParo', 'promoted_content': None, 'query': '%23YoNoParo', 'tweet_volume': 52456}, {'name': '#كم_سنه_لك_تسوق_سياره', 'url': 'http://twitter.com/search?q=%23%D9%83%D9%85_%D8%B3%D9%86%D9%87_%D9%84%D9%83_%D8%AA%D8%B3%D9%88%D9%82_%D8%B3%D9%8A%D8%A7%D8%B1%D9%87', 'promoted_content': None, 'query': '%23%D9%83%D9%85_%D8%B3%D9%86%D9%87 ...
# [{'trends': [{'name': '#NationalVoterRegistrationDay', 'url': 'http://twitter.com/search?q=%23NationalVoterRegistrationDay', 'promoted_content': None, 'query': '%23NationalVoterRegistrationDay', 'tweet_volume': 31490}, {'name': '#TuesdayThoughts', 'url': 'http://twitter.com/search?q=%23TuesdayThoughts', 'promoted_content': None, 'query': '%23TuesdayThoughts', 'tweet_volume': 70016}, {'name': 'Michael Kors', 'url': 'http://twitter.com/search?q=%22Michael+Kors%22', 'promoted_content': None, 'query': '%22Michael+Kors%22', 'tweet_volume': 37676}, {'name': '#FantasticBeasts', 'url': 'http://twitter.com/search?q=%23FantasticBeasts', 'promoted_content': None, 'query': '%23FantasticBeasts', 'tweet_volume': 94250}, {'name': '#WomenWhoLead', 'url': 'http://twitter.com/search?q=%23WomenWhoLead', 'promoted_content': None, 'query': '%23WomenWhoLead', 'tweet_volume': None}, {'name': 'Meltan', 'url': 'http://twitter.com/search?q=Meltan', 'promoted_content': None, 'query': 'Meltan', 'tweet_volume': 20252}, {'name': '#bookbirthday', 'url': 'http://twitter.com/search?q=%23bookbirthday', 'promoted_content': None, 'query': '%23bookbirthday', 'tweet_volume': None}, {'name': 'FOR A MUSE OF FIRE', 'url': 'http://twitter.com/search?q=%22FOR+A+MUSE+OF+FIRE%22', 'promoted_content': None, 'query': '%22FOR+A+MUSE+OF+FIRE%22', 'tweet_volume': None}, {'name': 'say something', 'url': 'http://twitter.com/search?q=%22say+something%22', 'promoted_content': None, 'query': '%22say+something%22', 'tweet_volume': 20107}, {'name': 'C Jon Toth', 'url': 'http://twitter.com/search?q=%22C+Jon+Toth%22', 'promoted_content': None, 'query': '%22C+Jon+Toth%22', 'tweet_volume': None}, {'name': 'UNGA', 'url': 'http://twitter.com/search?q=UNGA', 'promoted_content': None, 'query': 'UNGA', 'tweet_volume': 2653746}, {'name': 'Inspire Brands', 'url': 'http://twitter.com/search?q=%22Inspire+Brands%22', 'promoted_content': None, 'query': '%22Inspire+Brands%22', 'tweet_volume': None}, {'name': 'Dave Matthews Band', 'url': 'http://twitter.com/search?q=%22Dave+Matthews+Band%22', 'promoted_content': None, 'query': '%22Dave+Matthews+Band%22', 'tweet_volume': None}, {'name': 'William Faulkner', 'url': 'http://twitter.com/search?q=%22William+Faulkner%22', 'promoted_content': None, 'query': '%22William+Faulkner%22', 'tweet_volume': None}, {'name': 'BLACK WINGS BEATING', 'url': 'http://twitter.com/search?q=%22BLACK+WINGS+BEATING%22', 'promoted_content': None, 'query': '%22BLACK+WINGS+BEATING%22', 'tweet_volume': None}, {'name': 'Jerry Jones', 'url': 'http://twitter.com/search?q=%22Jerry+Jones%22', 'promoted_content': None, 'query': '%22Jerry+Jones%22', 'tweet_volume': None}, {'name': 'General Debate', 'url': 'http://twitter.com/search?q=%22General+Debate%22', 'promoted_content': None, 'query': '%22General+Debate%22', 'tweet_volume': None}, {'name': 'EITC', 'url': 'http://twitter.com/search?q=EITC', 'promoted_content': None, 'query': 'EITC', 'tweet_volume': None}, {'name': 'Sen. Ted Cruz', 'url': 'http://twitter.com/search?q=%22Sen.+Ted+Cruz%22', 'promoted_content': None, 'query': '%22Sen.+Ted+Cruz%22', 'tweet_volume': 12018}, {'name': 'Myrna Báez', 'url': 'http://twitter.com/search?q=%22Myrna+B%C3%A1ez%22', 'promoted_content': None, 'query': '%22Myrna+B%C3%A1ez%22', 'tweet_volume': None}, {'name': 'Allen Warner', 'url': 'http://twitter.com/search?q=%22Allen+Warner%22', 'promoted_content': None, 'query': '%22Allen+Warner%22', 'tweet_volume': None}, {'name': 'Operation Clear Track', 'url': 'http://twitter.com/search?q=%22Operation+Clear+Track%22', 'promoted_content': None, 'query': '%22Operation+Clear+Track%22', 'tweet_volume': None}, {'name': 'U.N. General Assembly', 'url': 'http://twitter.com/search?q=%22U.N.+General+Assembly%22', 'promoted_content': None, 'query': '%22U.N.+General+Assembly%22', 'tweet_volume': None}, {'name': 'Gary Keith and Ron', 'url': 'http://twitter.com/search?q=%22Gary+Keith+and+Ron%22', 'promoted_content': None, 'query': '%22Gary+Keith+and+Ron%22', 'tweet_volume': Non ...

# %% [markdown]
# ## Step 3. Displaying API responses as pretty-printed JSON

# %%
import json

print (json.dumps(world_trends, indent=1))
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#NationalVoterRegistrationDay",
#     "url": "http://twitter.com/search?q=%23NationalVoterRegistrationDay",
#     "promoted_content": null,
#     "query": "%23NationalVoterRegistrationDay",
#     "tweet_volume": 31490
#    },
#    {
#     "name": "Caputo",
#     "url": "http://twitter.com/search?q=Caputo",
#     "promoted_content": null,
#     "query": "Caputo",
#     "tweet_volume": 33073
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 36370
#    },
#    {
#     "name": "#FantasticBeasts",
#     "url": "http://twitter.com/search?q=%23FantasticBeasts",
#     "promoted_content": null,
#     "query": "%23FantasticBeasts",
#     "tweet_volume": 94250
#    },
#    {
#     "name": "#INDvAFG",
#     "url": "http://twitter.com/search?q=%23INDvAFG",
#     "promoted_content": null,
#     "query": "%23INDvAFG",
#     "tweet_volume": 31758
#    },
#    {
#     "name": "#EleSimENo1Turno",
#     "url": "http://twitter.com/search?q=%23EleSimENo1Turno",
#     "promoted_content": null,
#     "query": "%23EleSimENo1Turno",
#     "tweet_volume": 43322
#    },
#    {
#     "name": "\ub0b4\uae30\ub2c8",
#     "url": "http://twitter.com/search?q=%EB%82%B4%EA%B8%B0%EB%8B%88",
#     "promoted_content": null,
#     "query": "%EB%82%B4%EA%B8%B0%EB%8B%88",
#     "tweet_volume": 11714
#    },
#    {
#     "name": "Meltan",
#     "url": "http://twitter.com/search?q=Meltan",
#     "promoted_content": null,
#     "query": "Meltan",
#     "tweet_volume": 20252
#    },
#    {
#     "name": "\u30e1\u30eb\u30bf\u30f3",
#     "url": "http://twitter.com/search?q=%E3%83%A1%E3%83%AB%E3%82%BF%E3%83%B3",
#     "promoted_content": null,
#     "query": "%E3%83%A1%E3%83%AB%E3%82%BF%E3%83%B3",
#     "tweet_volume": 85511
#    },
#    {
#     "name": "Michael Kors",
#     "url": "http://twitter.com/search?q=%22Michael+Kors%22",
#     "promoted_content": null,
#     "query": "%22Michael+Kors%22",
#     "tweet_volume": 37676
#    },
#    {
#     "name": "\uc870\ub2c8\ub381",
#     "url": "http://twitter.com/search?q=%EC%A1%B0%EB%8B%88%EB%8E%81",
#     "promoted_content": null,
#     "query": "%EC%A1%B0%EB%8B%88%EB%8E%81",
#     "tweet_volume": null
#    },
#    {
#     "name": "Toto",
#     "url": "http://twitter.com/search?q=Toto",
#     "promoted_content": null,
#     "query": "Toto",
#     "tweet_volume": 26782
#    },
#    {
#     "name": "\uc2e0\ub3d9\uc0ac",
#     "url": "http://twitter.com/search?q=%EC%8B%A0%EB%8F%99%EC%82%AC",
#     "promoted_content": null,
#     "query": "%EC%8B%A0%EB%8F%99%EC%82%AC",
#     "tweet_volume": null
#    },
#    {
#     "name": "\ubcfc\ub4dc\ubaa8\ud2b8",
#     "url": "http://twitter.com/search?q=%EB%B3%BC%EB%93%9C%EB%AA%A8%ED%8A%B8",
#     "promoted_content": null,
#     "query": "%EB%B3%BC%EB%93%9C%EB%AA%A8%ED%8A%B8",
#     "tweet_volume": 10826
#    },
#    {
#     "name": "\u65b0\u6f6e45",
#     "url": "http://twitter.com/search?q=%E6%96%B0%E6%BD%AE45",
#     "promoted_content": null,
#     "query": "%E6%96%B0%E6%BD%AE45",
#     "tweet_volume": 47201
#    },
#    {
#     "name": "\u30e4\u30af\u30eb\u30c8",
#     "url": "http://twitter.com/search?q=%E3%83%A4%E3%82%AF%E3%83%AB%E3%83%88",
#     "promoted_content": null,
#     "query": "%E3%83%A4%E3%82%AF%E3%83%AB%E3%83%88",
#     "tweet_volume": 58889
#    },
#    {
#     "name": "\ub9d0\ub808\ub515\ud22c\uc2a4",
#     "url": "http://twitter.com/search?q=%EB%A7%90%EB%A0%88%EB%94%95%ED%88%AC%EC%8A%A4",
#     "promoted_content": null,
#     "query": "%EB%A7%90%EB%A0%88%EB%94%95%ED%88%AC%EC%8A%A4",
#     "tweet_volume": null
#    },
#    {
#     "name": "Marlaska",
#     "url": "http://twitter.com/search?q=Marlaska",
#     "promoted_content": null,
#     "query": "Marlaska",
#     "tweet_volume": 51515
#    },
#    {
#     "name": "Faltam 12",
#     "url": "http://twitter.com/search?q=%22Faltam+12%22",
#     "promoted_content": null,
#     "query": "%22Faltam+12%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\ud574\ub9ac\ud3ec\ud130",
#     "url": "http://twitter.com/search?q=%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0",
#     "promoted_content": null,
#     "query": "%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0",
#     "tweet_volume": null
#    },
#    {
#     "name": "Thames",
#     "url": "http://twitter.com/search?q=Thames",
#     "promoted_content": null,
#     "query": "Thames",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sauber",
#     "url": "http://twitter.com/search?q=Sauber",
#     "promoted_content": null,
#     "query": "Sauber",
#     "tweet_volume": null
#    },
#    {
#     "name": "#YoNoParo",
#     "url": "http://twitter.com/search?q=%23YoNoParo",
#     "promoted_content": null,
#     "query": "%23YoNoParo",
#     "tweet_volume": 52456
#    },
#    {
#     "name": "#\u0643\u0645_\u0633\u0646\u0647_\u0644\u0643_\u062a\u0633\u0648\u0642_\u0633\u064a\u0627\u0631\u0647",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%85_%D8%B3%D9%86%D9%87_%D9%84%D9%83_%D8%AA%D8%B3%D9%88%D9%82_%D8%B3%D9%8A%D8%A7%D8%B1%D9%87",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%85_%D8%B3%D9%86%D9%87_%D9%84%D9%83_%D8%AA%D8%B3%D9%88%D9%82_%D8%B3%D9%8A%D8%A7%D8%B1%D9%87",
#     "tweet_volume": 13792
#    },
#    {
#     "name": "#25Sep",
#     "url": "http://twitter.com/search?q=%2325Sep",
#     "promoted_content": null,
#     "query": "%2325Sep",
#     "tweet_volume": 25121
#    },
#    {
#     "name": "#\u0627\u0644\u0645\u0631\u0627\u0647_\u0648\u0634_\u0647\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D8%B1%D8%A7%D9%87_%D9%88%D8%B4_%D9%87%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D9%85%D8%B1%D8%A7%D9%87_%D9%88%D8%B4_%D9%87%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TuesdayThoughts",
#     "url": "http://twitter.com/search?q=%23TuesdayThoughts",
#     "promoted_content": null,
#     "query": "%23TuesdayThoughts",
#     "tweet_volume": 70016
#    },
#    {
#     "name": "#OTDirecto25SEP",
#     "url": "http://twitter.com/search?q=%23OTDirecto25SEP",
#     "promoted_content": null,
#     "query": "%23OTDirecto25SEP",
#     "tweet_volume": 33693
#    },
#    {
#     "name": "#\u0642\u0637\u0627\u0631_\u0627\u0644\u062d\u0631\u0645\u064a\u0646_\u0627\u0644\u0633\u0631\u064a\u0639",
#     "url": "http://twitter.com/search?q=%23%D9%82%D8%B7%D8%A7%D8%B1_%D8%A7%D9%84%D8%AD%D8%B1%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D8%B3%D8%B1%D9%8A%D8%B9",
#     "promoted_content": null,
#     "query": "%23%D9%82%D8%B7%D8%A7%D8%B1_%D8%A7%D9%84%D8%AD%D8%B1%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D8%B3%D8%B1%D9%8A%D8%B9",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WorldIsBiggerThan5",
#     "url": "http://twitter.com/search?q=%23WorldIsBiggerThan5",
#     "promoted_content": null,
#     "query": "%23WorldIsBiggerThan5",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ParoNacional",
#     "url": "http://twitter.com/search?q=%23ParoNacional",
#     "promoted_content": null,
#     "query": "%23ParoNacional",
#     "tweet_volume": 18446
#    },
#    {
#     "name": "#Ne\u015fetErta\u015f",
#     "url": "http://twitter.com/search?q=%23Ne%C5%9FetErta%C5%9F",
#     "promoted_content": null,
#     "query": "%23Ne%C5%9FetErta%C5%9F",
#     "tweet_volume": 110244
#    },
#    {
#     "name": "#\uace0\uae30_\ud638\ubd88\ud638",
#     "url": "http://twitter.com/search?q=%23%EA%B3%A0%EA%B8%B0_%ED%98%B8%EB%B6%88%ED%98%B8",
#     "promoted_content": null,
#     "query": "%23%EA%B3%A0%EA%B8%B0_%ED%98%B8%EB%B6%88%ED%98%B8",
#     "tweet_volume": null
#    },
#    {
#     "name": "#D\u00edaNaranja",
#     "url": "http://twitter.com/search?q=%23D%C3%ADaNaranja",
#     "promoted_content": null,
#     "query": "%23D%C3%ADaNaranja",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\uc774_\ud574\uc2dc\ub97c_\ubcf4\ub294\uc21c\uac04_\ucde8\ud5a5\uc678\uce58\uae30",
#     "url": "http://twitter.com/search?q=%23%EC%9D%B4_%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%8A%94%EC%88%9C%EA%B0%84_%EC%B7%A8%ED%96%A5%EC%99%B8%EC%B9%98%EA%B8%B0",
#     "promoted_content": null,
#     "query": "%23%EC%9D%B4_%ED%95%B4%EC%8B%9C%EB%A5%BC_%EB%B3%B4%EB%8A%94%EC%88%9C%EA%B0%84_%EC%B7%A8%ED%96%A5%EC%99%B8%EC%B9%98%EA%B8%B0",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\uc2a4\ucfe8\ubbf8\ud22c",
#     "url": "http://twitter.com/search?q=%23%EC%8A%A4%EC%BF%A8%EB%AF%B8%ED%88%AC",
#     "promoted_content": null,
#     "query": "%23%EC%8A%A4%EC%BF%A8%EB%AF%B8%ED%88%AC",
#     "tweet_volume": 225535
#    },
#    {
#     "name": "#\u0643\u0644\u0646\u0627_\u0627\u062d\u0645\u062f_\u0639\u0633\u064a\u0631\u064a",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%86%D8%A7_%D8%A7%D8%AD%D9%85%D8%AF_%D8%B9%D8%B3%D9%8A%D8%B1%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%84%D9%86%D8%A7_%D8%A7%D8%AD%D9%85%D8%AF_%D8%B9%D8%B3%D9%8A%D8%B1%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#T\u30b7\u30e3\u30c4\u306b\u3057\u305f\u3044\u6620\u753b\u4f01\u696d\u30ed\u30b4",
#     "url": "http://twitter.com/search?q=%23T%E3%82%B7%E3%83%A3%E3%83%84%E3%81%AB%E3%81%97%E3%81%9F%E3%81%84%E6%98%A0%E7%94%BB%E4%BC%81%E6%A5%AD%E3%83%AD%E3%82%B4",
#     "promoted_content": null,
#     "query": "%23T%E3%82%B7%E3%83%A3%E3%83%84%E3%81%AB%E3%81%97%E3%81%9F%E3%81%84%E6%98%A0%E7%94%BB%E4%BC%81%E6%A5%AD%E3%83%AD%E3%82%B4",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0644\u0627_\u062a\u0631\u0643\u064a_\u0627\u0644_\u0627\u0644\u0634\u064a\u062e",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7_%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%A7_%D8%AA%D8%B1%D9%83%D9%8A_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE",
#     "tweet_volume": 101284
#    },
#    {
#     "name": "#OQueEstaFaltando\u00c9",
#     "url": "http://twitter.com/search?q=%23OQueEstaFaltando%C3%89",
#     "promoted_content": null,
#     "query": "%23OQueEstaFaltando%C3%89",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SACBA",
#     "url": "http://twitter.com/search?q=%23SACBA",
#     "promoted_content": null,
#     "query": "%23SACBA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ElevateTechFest",
#     "url": "http://twitter.com/search?q=%23ElevateTechFest",
#     "promoted_content": null,
#     "query": "%23ElevateTechFest",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GHVIP25S",
#     "url": "http://twitter.com/search?q=%23GHVIP25S",
#     "promoted_content": null,
#     "query": "%23GHVIP25S",
#     "tweet_volume": 12716
#    },
#    {
#     "name": "#\u6f14\u6b4c\u306e\u4e71",
#     "url": "http://twitter.com/search?q=%23%E6%BC%94%E6%AD%8C%E3%81%AE%E4%B9%B1",
#     "promoted_content": null,
#     "query": "%23%E6%BC%94%E6%AD%8C%E3%81%AE%E4%B9%B1",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u597d\u304d\u306a\u5bff\u53f8\u30cd\u30bf\u3067TL\u3092\u57cb\u3081\u308d\u65e9\u6025\u306b\u3060",
#     "url": "http://twitter.com/search?q=%23%E5%A5%BD%E3%81%8D%E3%81%AA%E5%AF%BF%E5%8F%B8%E3%83%8D%E3%82%BF%E3%81%A7TL%E3%82%92%E5%9F%8B%E3%82%81%E3%82%8D%E6%97%A9%E6%80%A5%E3%81%AB%E3%81%A0",
#     "promoted_content": null,
#     "query": "%23%E5%A5%BD%E3%81%8D%E3%81%AA%E5%AF%BF%E5%8F%B8%E3%83%8D%E3%82%BF%E3%81%A7TL%E3%82%92%E5%9F%8B%E3%82%81%E3%82%8D%E6%97%A9%E6%80%A5%E3%81%AB%E3%81%A0",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RatsasanAudioLaunch",
#     "url": "http://twitter.com/search?q=%23RatsasanAudioLaunch",
#     "promoted_content": null,
#     "query": "%23RatsasanAudioLaunch",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LiamMillerTribute",
#     "url": "http://twitter.com/search?q=%23LiamMillerTribute",
#     "promoted_content": null,
#     "query": "%23LiamMillerTribute",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheApprentice",
#     "url": "http://twitter.com/search?q=%23TheApprentice",
#     "promoted_content": null,
#     "query": "%23TheApprentice",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WomenWhoLead",
#     "url": "http://twitter.com/search?q=%23WomenWhoLead",
#     "promoted_content": null,
#     "query": "%23WomenWhoLead",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LuanMelhorClipeTVZ",
#     "url": "http://twitter.com/search?q=%23LuanMelhorClipeTVZ",
#     "promoted_content": null,
#     "query": "%23LuanMelhorClipeTVZ",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-09-25T14:27:37Z",
#   "created_at": "2018-09-25T14:22:39Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "#NationalVoterRegistrationDay",
#     "url": "http://twitter.com/search?q=%23NationalVoterRegistrationDay",
#     "promoted_content": null,
#     "query": "%23NationalVoterRegistrationDay",
#     "tweet_volume": 31490
#    },
#    {
#     "name": "#TuesdayThoughts",
#     "url": "http://twitter.com/search?q=%23TuesdayThoughts",
#     "promoted_content": null,
#     "query": "%23TuesdayThoughts",
#     "tweet_volume": 70016
#    },
#    {
#     "name": "Michael Kors",
#     "url": "http://twitter.com/search?q=%22Michael+Kors%22",
#     "promoted_content": null,
#     "query": "%22Michael+Kors%22",
#     "tweet_volume": 37676
#    },
#    {
#     "name": "#FantasticBeasts",
#     "url": "http://twitter.com/search?q=%23FantasticBeasts",
#     "promoted_content": null,
#     "query": "%23FantasticBeasts",
#     "tweet_volume": 94250
#    },
#    {
#     "name": "#WomenWhoLead",
#     "url": "http://twitter.com/search?q=%23WomenWhoLead",
#     "promoted_content": null,
#     "query": "%23WomenWhoLead",
#     "tweet_volume": null
#    },
#    {
#     "name": "Meltan",
#     "url": "http://twitter.com/search?q=Meltan",
#     "promoted_content": null,
#     "query": "Meltan",
#     "tweet_volume": 20252
#    },
#    {
#     "name": "#bookbirthday",
#     "url": "http://twitter.com/search?q=%23bookbirthday",
#     "promoted_content": null,
#     "query": "%23bookbirthday",
#     "tweet_volume": null
#    },
#    {
#     "name": "FOR A MUSE OF FIRE",
#     "url": "http://twitter.com/search?q=%22FOR+A+MUSE+OF+FIRE%22",
#     "promoted_content": null,
#     "query": "%22FOR+A+MUSE+OF+FIRE%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "say something",
#     "url": "http://twitter.com/search?q=%22say+something%22",
#     "promoted_content": null,
#     "query": "%22say+something%22",
#     "tweet_volume": 20107
#    },
#    {
#     "name": "C Jon Toth",
#     "url": "http://twitter.com/search?q=%22C+Jon+Toth%22",
#     "promoted_content": null,
#     "query": "%22C+Jon+Toth%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "UNGA",
#     "url": "http://twitter.com/search?q=UNGA",
#     "promoted_content": null,
#     "query": "UNGA",
#     "tweet_volume": 2653746
#    },
#    {
#     "name": "Inspire Brands",
#     "url": "http://twitter.com/search?q=%22Inspire+Brands%22",
#     "promoted_content": null,
#     "query": "%22Inspire+Brands%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dave Matthews Band",
#     "url": "http://twitter.com/search?q=%22Dave+Matthews+Band%22",
#     "promoted_content": null,
#     "query": "%22Dave+Matthews+Band%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "William Faulkner",
#     "url": "http://twitter.com/search?q=%22William+Faulkner%22",
#     "promoted_content": null,
#     "query": "%22William+Faulkner%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "BLACK WINGS BEATING",
#     "url": "http://twitter.com/search?q=%22BLACK+WINGS+BEATING%22",
#     "promoted_content": null,
#     "query": "%22BLACK+WINGS+BEATING%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jerry Jones",
#     "url": "http://twitter.com/search?q=%22Jerry+Jones%22",
#     "promoted_content": null,
#     "query": "%22Jerry+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "General Debate",
#     "url": "http://twitter.com/search?q=%22General+Debate%22",
#     "promoted_content": null,
#     "query": "%22General+Debate%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "EITC",
#     "url": "http://twitter.com/search?q=EITC",
#     "promoted_content": null,
#     "query": "EITC",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sen. Ted Cruz",
#     "url": "http://twitter.com/search?q=%22Sen.+Ted+Cruz%22",
#     "promoted_content": null,
#     "query": "%22Sen.+Ted+Cruz%22",
#     "tweet_volume": 12018
#    },
#    {
#     "name": "Myrna B\u00e1ez",
#     "url": "http://twitter.com/search?q=%22Myrna+B%C3%A1ez%22",
#     "promoted_content": null,
#     "query": "%22Myrna+B%C3%A1ez%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Allen Warner",
#     "url": "http://twitter.com/search?q=%22Allen+Warner%22",
#     "promoted_content": null,
#     "query": "%22Allen+Warner%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Operation Clear Track",
#     "url": "http://twitter.com/search?q=%22Operation+Clear+Track%22",
#     "promoted_content": null,
#     "query": "%22Operation+Clear+Track%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "U.N. General Assembly",
#     "url": "http://twitter.com/search?q=%22U.N.+General+Assembly%22",
#     "promoted_content": null,
#     "query": "%22U.N.+General+Assembly%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gary Keith and Ron",
#     "url": "http://twitter.com/search?q=%22Gary+Keith+and+Ron%22",
#     "promoted_content": null,
#     "query": "%22Gary+Keith+and+Ron%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Renate Alumni",
#     "url": "http://twitter.com/search?q=%22Renate+Alumni%22",
#     "promoted_content": null,
#     "query": "%22Renate+Alumni%22",
#     "tweet_volume": 13654
#    },
#    {
#     "name": "NCDs",
#     "url": "http://twitter.com/search?q=NCDs",
#     "promoted_content": null,
#     "query": "NCDs",
#     "tweet_volume": null
#    },
#    {
#     "name": "NB 101",
#     "url": "http://twitter.com/search?q=%22NB+101%22",
#     "promoted_content": null,
#     "query": "%22NB+101%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WorkRedux",
#     "url": "http://twitter.com/search?q=%23WorkRedux",
#     "promoted_content": null,
#     "query": "%23WorkRedux",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SpringOne",
#     "url": "http://twitter.com/search?q=%23SpringOne",
#     "promoted_content": null,
#     "query": "%23SpringOne",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MathASentence",
#     "url": "http://twitter.com/search?q=%23MathASentence",
#     "promoted_content": null,
#     "query": "%23MathASentence",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheOpportunityMyth",
#     "url": "http://twitter.com/search?q=%23TheOpportunityMyth",
#     "promoted_content": null,
#     "query": "%23TheOpportunityMyth",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MorningJoe",
#     "url": "http://twitter.com/search?q=%23MorningJoe",
#     "promoted_content": null,
#     "query": "%23MorningJoe",
#     "tweet_volume": 13394
#    },
#    {
#     "name": "#OneHitWonderDay",
#     "url": "http://twitter.com/search?q=%23OneHitWonderDay",
#     "promoted_content": null,
#     "query": "%23OneHitWonderDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#INDvAFG",
#     "url": "http://twitter.com/search?q=%23INDvAFG",
#     "promoted_content": null,
#     "query": "%23INDvAFG",
#     "tweet_volume": 31758
#    },
#    {
#     "name": "#NRPAConference",
#     "url": "http://twitter.com/search?q=%23NRPAConference",
#     "promoted_content": null,
#     "query": "%23NRPAConference",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Inforum2018",
#     "url": "http://twitter.com/search?q=%23Inforum2018",
#     "promoted_content": null,
#     "query": "%23Inforum2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 36370
#    },
#    {
#     "name": "#smartoncrime",
#     "url": "http://twitter.com/search?q=%23smartoncrime",
#     "promoted_content": null,
#     "query": "%23smartoncrime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BD4SG",
#     "url": "http://twitter.com/search?q=%23BD4SG",
#     "promoted_content": null,
#     "query": "%23BD4SG",
#     "tweet_volume": null
#    },
#    {
#     "name": "#thatcc",
#     "url": "http://twitter.com/search?q=%23thatcc",
#     "promoted_content": null,
#     "query": "%23thatcc",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WhyISeeSay",
#     "url": "http://twitter.com/search?q=%23WhyISeeSay",
#     "promoted_content": null,
#     "query": "%23WhyISeeSay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AM2DM",
#     "url": "http://twitter.com/search?q=%23AM2DM",
#     "promoted_content": null,
#     "query": "%23AM2DM",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RyderCupCelebMatch",
#     "url": "http://twitter.com/search?q=%23RyderCupCelebMatch",
#     "promoted_content": null,
#     "query": "%23RyderCupCelebMatch",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CBSChicagoCares",
#     "url": "http://twitter.com/search?q=%23CBSChicagoCares",
#     "promoted_content": null,
#     "query": "%23CBSChicagoCares",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Photokina2018",
#     "url": "http://twitter.com/search?q=%23Photokina2018",
#     "promoted_content": null,
#     "query": "%23Photokina2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OUGivingDay",
#     "url": "http://twitter.com/search?q=%23OUGivingDay",
#     "promoted_content": null,
#     "query": "%23OUGivingDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GLAF2018",
#     "url": "http://twitter.com/search?q=%23GLAF2018",
#     "promoted_content": null,
#     "query": "%23GLAF2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WillSmith",
#     "url": "http://twitter.com/search?q=%23WillSmith",
#     "promoted_content": null,
#     "query": "%23WillSmith",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SourceCon",
#     "url": "http://twitter.com/search?q=%23SourceCon",
#     "promoted_content": null,
#     "query": "%23SourceCon",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FH4Goodwood",
#     "url": "http://twitter.com/search?q=%23FH4Goodwood",
#     "promoted_content": null,
#     "query": "%23FH4Goodwood",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-09-25T14:27:37Z",
#   "created_at": "2018-09-25T14:22:39Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# Take a look at the [api docs](https://dev.twitter.com/rest/reference/get/trends/place) for the /trends/place call made above.

# %% [markdown]
# ## Step 4. Collecting search results for a targeted hashtag.

# %%
# Import unquote to prevent url encoding errors in next_results
#from urllib3 import unquote

#This can be any trending topic, but let's focus on a hashtag that is relevant to the class. 
q = '#analytics' 

count = 100

# See https://dev.twitter.com/rest/reference/get/search/tweets
search_results = twitter.search.tweets(q=q, count=count)

#This selects out 
statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor
for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
        print ("next_results", next_results)
    except: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    print (kwargs)
    search_results = twitter.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# next_results ?max_id=1044590656306511872&q=%23analytics&count=100&include_entities=1
# {'max_id': '1044590656306511872', 'q': '%23analytics', 'count': '100', 'include_entities': '1'}
# Length of statuses 200
# next_results ?max_id=1044585942693031936&q=%2523analytics&count=100&include_entities=1
# {'max_id': '1044585942693031936', 'q': '%2523analytics', 'count': '100', 'include_entities': '1'}
# Length of statuses 200
# {
#  "created_at": "Tue Sep 25 14:28:36 +0000 2018",
#  "id": 1044594521403772928,
#  "id_str": "1044594521403772928",
#  "text": "RT @MicroStrategy: ICYMI, @BARC_Research named MicroStrategy an #analytics market leader, citing its strengths of \"tight integration of sel\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "analytics",
#     "indices": [
#      64,
#      74
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MicroStrategy",
#     "name": "MicroStrategy",
#     "id": 14883246,
#     "id_str": "14883246",
#     "indices": [
#      3,
#      17
#     ]
#    },
#    {
#     "screen_name": "BARC_Research",
#     "name": "BARC",
#     "id": 949394238,
#     "id_str": "949394238",
#     "indices": [
#      26,
#      40
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://gaggleamp.com/twit/\" rel=\"nofollow\">GaggleAMP</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 45821436,
#   "id_str": "45821436",
#   "name": "Gabriella Callegari",
#   "screen_name": "GabbyMS",
#   "location": "Views are my own",
#   "description": "Marketing professional at MicroStrategy. Juggling the demands of life. Supporting local charities. Tiramisu maker.",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 101,
#   "friends_count": 328,
#   "listed_count": 4,
#   "created_at": "Tue Jun 09 12:02:41 +0000 2009",
#   "favourites_count": 768,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 563,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000375240664/387a894475909cf954997f4e583edadd_normal.jpeg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000375240664/387a894475909cf954997f4e583edadd_normal.jpeg",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sun Sep 23 13:55:06 +0000 2018",
#   "id": 1043861317348708357,
#   "id_str": "1043861317348708357",
#   "text": "ICYMI, @BARC_Research named MicroStrategy an #analytics market leader, citing its strengths of \"tight integration o\u2026 https://t.co/gF2VvB51Ur",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "analytics",
#      "indices": [
#       45,
#       55
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "BARC_Research",
#      "name": "BARC",
#      "id": 949394238,
#      "id_str": "949394238",
#      "indices": [
#       7,
#       21
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/gF2VvB51Ur",
#      "expanded_url": "https://twitter.com/i/web/status/1043861317348708357",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 14883246,
#    "id_str": "14883246",
#    "name": "MicroStrategy",
#    "screen_name": "MicroStrategy",
#    "location": "Tysons Corner, VA",
#    "description": "Leading worldwide provider of enterprise #analytics and #mobility software. https://t.co/zWknLLH8WK",
#    "url": "http://t.co/DRKSzFARRv",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/DRKSzFARRv",
#        "expanded_url": "http://www.microstrategy.com",
#        "display_url": "microstrategy.com",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "https://t.co/zWknLLH8WK",
#        "expanded_url": "https://www.microstrategy.com",
#        "display_url": "microstrategy.com",
#        "indices": [
#         76,
#         99
#        ]
#       }
#      ]
#     }
#    },
#    "protected": false,
#    "followers_count": 48641,
#    "friends_count": 3656,
#    "listed_count": 1089,
#    "created_at": "Fri May 23 16:05:19 +0000 2008",
#    "favourites_count": 5202,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 8866,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "EBEBEB",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/875397841862242304/9_3NVOAY_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/875397841862242304/9_3NVOAY_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/14883246/1516391303",
#    "profile_link_color": "CC0000",
#    "profile_sidebar_border_color": "CC0000",
#    "profile_sidebar_fill_color": "FFFFFF",
#    "profile_text_color": "000000",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 46,
#   "favorite_count": 3,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 46,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
#Print several
print (json.dumps(statuses[0:5], indent=1))

# %% [markdown]
# ## Step 5. Extracting text, screen names, and hashtags from tweets

# %%
#We can access an individual tweet like so:
statuses[1]['text']
# Out:
# 'RT @Harry_Robots: 12 Facts you need to know about #IoT and its usage and implications #Infographic #IIoT #CyberSecurity #BigData #infosec #…'

# %%
statuses[1]['entities']
# Out:
# {'hashtags': [{'indices': [50, 54], 'text': 'IoT'},
#   {'indices': [86, 98], 'text': 'Infographic'},
#   {'indices': [99, 104], 'text': 'IIoT'},
#   {'indices': [105, 119], 'text': 'CyberSecurity'},
#   {'indices': [120, 128], 'text': 'BigData'},
#   {'indices': [129, 137], 'text': 'infosec'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 973892651522166785,
#    'id_str': '973892651522166785',
#    'indices': [3, 16],
#    'name': 'Harry Miller',
#    'screen_name': 'Harry_Robots'}]}

# %%
#notice the nested relationships.  We have to take notice of this to further access the data.
statuses[1]['entities']['hashtags']
# Out:
# [{'indices': [50, 54], 'text': 'IoT'},
#  {'indices': [86, 98], 'text': 'Infographic'},
#  {'indices': [99, 104], 'text': 'IIoT'},
#  {'indices': [105, 119], 'text': 'CyberSecurity'},
#  {'indices': [120, 128], 'text': 'BigData'},
#  {'indices': [129, 137], 'text': 'infosec'}]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

urls = [ url['url'] 
             for status in statuses
                 for url in status['entities']['urls'] ]



# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1)) 
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @MicroStrategy: ICYMI, @BARC_Research named MicroStrategy an #analytics market leader, citing its strengths of \"tight integration of sel\u2026",
#  "RT @Harry_Robots: 12 Facts you need to know about #IoT and its usage and implications #Infographic #IIoT #CyberSecurity #BigData #infosec #\u2026",
#  "RT @R_Demidchuk: Completo informe de Gartner con 100 predicciones sobre #Analytics y #BigData, y c\u00f3mo se potencian al interactuar con otras\u2026",
#  "RT @Ronald_vanLoon: 9 Types of #Intelligence [#INFOGRAPHICS]\n\n#ArtificialIntelligence #AI #3D #BigData #VirtualReality #VR #Analytics #UX #\u2026",
#  "RT @ahmedjr_16: 48 Best #Development Courses \n\nhttps://t.co/y3DBJGYs64 \n\n#AI #gamedev #indiedev #indiegame #games #game #unity #100daysofCo\u2026"
# ]
# [
#  "MicroStrategy",
#  "BARC_Research",
#  "Harry_Robots",
#  "R_Demidchuk",
#  "Ronald_vanLoon"
# ]
# [
#  "analytics",
#  "IoT",
#  "Infographic",
#  "IIoT",
#  "CyberSecurity"
# ]
# [
#  "RT",
#  "@MicroStrategy:",
#  "ICYMI,",
#  "@BARC_Research",
#  "named"
# ]

# %% [markdown]
# ## Step 6. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # top 10, "\n")
# Out:
# [('RT', 114), ('to', 79), ('the', 63), ('and', 54), ('in', 48), ('#Analytics', 46), ('of', 37), ('for', 30), ('with', 29), ('#analytics', 27)]
# [('Fisher85M', 17), ('MicroStrategy', 14), ('NeilCattermull', 8), ('FinMasonInc', 5), ('BARC_Research', 4), ('AiDirectory', 4), ('bamitav', 4), ('Ronald_vanLoon', 3), ('Flipkart', 3), ('upstreamcomm', 3)]
# [('Analytics', 52), ('analytics', 34), ('AI', 26), ('BigData', 25), ('IoT', 10), ('CyberSecurity', 10), ('infosec', 10), ('data', 9), ('Security', 8), ('GDPR', 8)]
